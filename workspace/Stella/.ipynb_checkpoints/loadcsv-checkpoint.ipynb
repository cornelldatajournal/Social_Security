# %%
import csv
with open('SSI-State-Age-2010.csv', mode ='r')as file:
  csvFile = csv.reader(file)
  for lines in csvFile:
        print(lines)
# Out:
# ['STATE', ' AGE  ', 'SEX', 'RECIPIENTS']
# ['AK   ', '  <05 ', 'F  ', '        84']
# ['AK   ', '  <05 ', 'M  ', '       128']
# ['AK   ', ' 05-12', 'F  ', '       196']
# ['AK   ', ' 05-12', 'M  ', '       407']
# ['AK   ', ' 13-17', 'F  ', '       154']
# ['AK   ', ' 13-17', 'M  ', '       270']
# ['AK   ', ' 18-21', 'F  ', '       242']
# ['AK   ', ' 18-21', 'M  ', '       388']
# ['AK   ', ' 22-25', 'F  ', '       270']
# ['AK   ', ' 22-25', 'M  ', '       359']
# ['AK   ', ' 26-29', 'F  ', '       226']
# ['AK   ', ' 26-29', 'M  ', '       317']
# ['AK   ', ' 30-39', 'F  ', '       523']
# ['AK   ', ' 30-39', 'M  ', '       497']
# ['AK   ', ' 40-49', 'F  ', '       994']
# ['AK   ', ' 40-49', 'M  ', '       668']
# ['AK   ', ' 50-59', 'F  ', '      1425']
# ['AK   ', ' 50-59', 'M  ', '      1109']
# ['AK   ', ' 60-64', 'F  ', '       534']
# ['AK   ', ' 60-64', 'M  ', '       420']
# ['AK   ', ' 65-69', 'F  ', '       502']
# ['AK   ', ' 65-69', 'M  ', '       314']
# ...
