# %% [markdown]
# # Analysis by Type of Beneficiary
#
# data from: https://www.ssa.gov/oact/progdata/icp.html

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import Files and info

df_raw = pd.read_excel("SS_Data_by_Type_of_Beneficiary2.xlsx")

beneficiary_types_ls = [
    
    "Retired_Worker",
    "Spouse_of_Retired_Worker",
    "Child_of_Retired_Worker",
    "Child_of_Deceased_Worker",
    "Aged_Widower",
    "Young_Widower_With_Child_In_Care",
    "Disabled_Widower",
    "Parent_of_Deceased_Worker",
    "Disabled_Worker",
    "Spouse_of_Disabled_Worker",
    "Child_of_Disabled_Worker"]

# %%
df_raw.head()
# Out:
#   End of Month  Retired_Worker_Total_Amount  \
# 0   1967-01-01                     11713055
# 1   1967-02-01                     11730905
# 2   1967-03-01                     11651066
# 3   1967-04-01                     11705026
# 4   1967-05-01                     11659549
#
#    Retired_Worker_Total_Average_Amount  Retired_Worker_Male_Number  \
# 0                                84.55                     7062629
# 1                                84.67                     7071093
# 2                                84.70                     7008957
# 3                                84.80                     7043619
# 4                                84.88                     7010336
#
#    Retired_Worker_Male_Average_Amount  Retired_Worker_Male_Female_Number  \
# 0                               93.49                            4650426
# 1                               93.63                            4659812
# 2                               93.69                            4642109
# 3                               93.82                            4661407
# 4                               93.92                            4649213
#
#    Retired_Worker_Female_Average_Amount  \
# 0                                 70.98
# 1                                 71.08
# 2                                 71.13
# 3                                 71.16
# 4                                 71.26
#
#    Spouse_of_Retired_Worker_Total_Number  \
# 0                                2641331
# 1                                2639607
# 2                                2606117
# 3                                2625954
# 4                                2605526
#
#    Spouse_of_Retired_Worker_Total_Average_Amount  \
# 0                                          43.90
# 1                                          43.94
# 2                                          43.94
# 3                                          43.99
# 4                                          44.03
#
#    Spouse_of_Retired_Worker_Male_Number  ...  \
# 0                                 11407  ...
# 1                                 10137  ...
# 2                                  9922  ...
# 3                                  9940  ...
# 4                                  9780  ...
#
#    Spouse_Of_Disabled_Worker_Female_Number  \
# 0                                   220669
# 1                                   221496
# 2                                   223169
# 3                                   222387
# 4                                   224726
#
#    Spouse_Of_Disabled_Worker_Female_Average_Amount  \
# 0                                            34.54
# 1                                            34.46
# 2                                            34.36
# 3                                            34.30
# 4                                            34.21
#
#    Child_Of_Disabled_Worker_Total_Number  \
# 0                                 659686
# 1                                 663373
# 2                                 672768
# 3                                 674502
# 4                                 685786
#
#    Child_Of_Disabled_Worker_Total_Average_Amount  \
# 0                                          31.38
# 1                                          31.37
# 2                                          31.34
# 3                                          31.35
# 4                                          31.33
#
#    Child_Of_Disabled_Worker_Minor_Number  \
# 0                                 605746
# 1                                 607712
# 2                                 614285
# 3                                 614701
# 4                                 622867
#
#    Child_Of_Disabled_Worker_Minor_Average_Amount  \
# 0                                          30.31
# 1                                          30.28
# 2                                          30.22
# 3                                          30.21
# 4                                          30.16
#
#    Child_Of_Disabled_Worker_Disabled_Number  \
# 0                                     10252
# 1                                     10318
# 2                                     10459
# 3                                     10593
# 4                                     10718
#
#    Child_Of_Disabled_Worker_Disabled_Average_Amount  \
# 0                                             41.17
# 1                                             41.22
# 2                                             41.13
# 3                                             41.08
# 4                                             41.00
#
#    Child_Of_Disabled_Worker_Student_Number  \
# 0                                    43688
# 1                                    45343
# 2                                    48024
# 3                                    49208
# 4                                    52201
#
#    Child_Of_Disabled_Worker_Student_Average_Amount
# 0                                            43.93
# 1                                            43.72
# 2                                            43.51
# 3                                            43.50
# 4                                            43.30
#
# [5 rows x 73 columns]

# %%
df_ben_nums = pd.concat([df_raw.iloc[:, 0], df_raw.iloc[:, 1],df_raw.filter(like='Total_Number')], axis=1)
df_ben_nums['Total'] = df_ben_nums.iloc[:, 1:].sum(axis = 1)
df_percent = pd.concat(
    [df_raw.iloc[:, 0].reset_index(drop=True), 
     df_ben_nums.iloc[:, 1:].div(df_ben_nums['Total'], axis=0).reset_index(drop=True)],
    axis=1
)
df_percent.head()
# Out:
#   End of Month  Retired_Worker_Total_Amount  \
# 0   1967-01-01                     0.527033
# 1   1967-02-01                     0.526693
# 2   1967-03-01                     0.524367
# 3   1967-04-01                     0.524419
# 4   1967-05-01                     0.522251
#
#    Spouse_of_Retired_Worker_Total_Number  \
# 0                               0.118848
# 1                               0.118513
# 2                               0.117291
# 3                               0.117650
# 4                               0.116706
#
#    Child_Of_Retired_Worker_Total_Number  \
# 0                              0.023011
# 1                              0.022935
# 2                              0.023019
# 3                              0.022924
# 4                              0.023058
#
#    Child_Of_Deceased_Worker_Total_Number  Aged_Widower_Total_Number  \
# 0                               0.100349                   0.117687
# 1                               0.100741                   0.118042
# 2                               0.101884                   0.119078
# 3                               0.102061                   0.119016
# 4                               0.103294                   0.119646
#
#    Young_Widower_With_Child_In_Care_Total_Number  \
# 0                                       0.021894
# 1                                       0.021889
# 2                                       0.022050
# 3                                       0.021820
# 4                                       0.021907
#
#    Disabled_Widower_Total_Number  Parent_Of_Deceased_Worker_Total_Number  \
# 0                            0.0                                0.001549
# 1                            0.0                                0.001541
# 2                            0.0                                0.001543
# 3                            0.0                                0.001530
# 4                            0.0                                0.001528
#
#    Disabled_Worker_Total_Number  Spouse_Of_Disabled_Worker_Total_Number  \
# 0                      0.049995                                0.009953
# 1                      0.049894                                0.009968
# 2                      0.050424                                0.010066
# 3                      0.050373                                0.009986
# 4                      0.050804                                0.010088
#
#    Child_Of_Disabled_Worker_Total_Number  Total
# 0                               0.029683    1.0
# 1                               0.029784    1.0
# 2                               0.030279    1.0
# 3                               0.030220    1.0
# 4                               0.030718    1.0

# %%
sns.set_theme()

y_columns = [
    "Retired_Worker_Total_Amount",
    "Spouse_of_Retired_Worker_Total_Number",
    "Child_Of_Retired_Worker_Total_Number",
    "Child_Of_Deceased_Worker_Total_Number",
    "Aged_Widower_Total_Number",
    "Young_Widower_With_Child_In_Care_Total_Number",
    "Disabled_Widower_Total_Number",
    "Parent_Of_Deceased_Worker_Total_Number",
    "Disabled_Worker_Total_Number",
    "Spouse_Of_Disabled_Worker_Total_Number",
    "Child_Of_Disabled_Worker_Total_Number"
]

legend_key = [ 
    "Retired Worker",
    "Spouse of Retired Worker",
    "Child of Retired Worker",
    "Child of Deceased Worker",
    "Aged Widower",
    "Young Widower With Child In Care",
    "Disabled Widower",
    "Parent of Deceased Worker",
    "Disabled Worker",
    "Spouse of Disabled Worker",
    "Child of Disabled Worker"]

plt.figure(figsize = (20, 6))


plt.stackplot(
    df_percent["End of Month"], 
    [df_percent[col] for col in y_columns]
)


plt.legend(legend_key, loc = 'lower right')

plt.show()

# %%
# function to extract data by type of worker

def extract_beneficiary_type(specified_beneficiary):
    x = df_raw.columns.str.startswith(specified_beneficiary) #gets the columns in an index with T and F
    x[0] = True #makes the date column from False to True
    df_return = df_raw[df_raw.columns[x]]
    return df_return

# %% [markdown]
# ## Retired Worker Analysis
#
# defined as "Retired worker—beneficiary who worked in covered employment long enough to be insured and who is at least 62 years old (benefits equal to the "primary insurance amount" are payable at the normal retirement age; maximum benefits are payable at age 70)"

# %%
Retired_Worker_df = extract_beneficiary_type(beneficiary_types_ls[0])

time = Retired_Worker_df["End of Month"]
y1 = Retired_Worker_df["Retired_Worker_Total_Amount"]
y2 = Retired_Worker_df["Retired_Worker_Total_Average_Amount"]

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time (Years)')
ax1.set_ylabel('Total Number', color=color)
ax1.plot(time, y1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel('Total Average Amount', color=color)
ax2.plot(time, y2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

plt.show()
